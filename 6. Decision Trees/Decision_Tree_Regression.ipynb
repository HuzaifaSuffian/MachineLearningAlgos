# %%
from sklearn.datasets import load_diabetes
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
X,y =load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
dtr = DecisionTreeRegressor(criterion='squared_error',max_depth=2)

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
y_pred = dtr.predict(X_test)

# %%
print('R2 score',r2_score(y_test,y_pred))
# Out:
# R2 score 0.34436074535670436

# %%
from sklearn.tree import plot_tree
plot_tree(dtr)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[8] <= -0.004\nsquared_error = 5811.375\nsamples = 353\nvalue = 152.113'),
#  Text(0.25, 0.5, 'x[2] <= 0.006\nsquared_error = 3055.934\nsamples = 174\nvalue = 109.701'),
#  Text(0.375, 0.6666666666666667, 'True  '),
#  Text(0.125, 0.16666666666666666, 'squared_error = 2254.403\nsamples = 142\nvalue = 97.458'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 2995.78\nsamples = 32\nvalue = 164.031'),
#  Text(0.75, 0.5, 'x[2] <= 0.056\nsquared_error = 5041.599\nsamples = 179\nvalue = 193.341'),
#  Text(0.625, 0.6666666666666667, '  False'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 4289.914\nsamples = 140\nvalue = 176.014'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 2793.736\nsamples = 39\nvalue = 255.538')]
